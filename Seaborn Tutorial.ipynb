# %% [markdown]
# ### Distribution Plots
# - displot
# - joinplot
# - pairplot

# %%
#practise problem on IRIS dataset
import seaborn as sns
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#extracting top 5 dataset
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Correlation with Heatmap
# A correlation heaptmap uses coloured cells, typically monochromatic scale to show a 2D correlation matrix(table) between two discrete dimensions or event types. It is very important in featues Selection

# %%
df.corr()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5208\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#let's calculaate total bill of all customers
df.total_bill.sum()
# Out:
# 4827.77

# %%
df.groupby('sex').total_bill.sum()
# Out:
# sex
# Male      3256.82
# Female    1570.95
# Name: total_bill, dtype: float64

# %%
sns.heatmap(df.corr());
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5208\2460615548.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr());

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ### Join Plot
# A join plot allows the relationship between  2 numeric variables. The central chart display their correlation. It is usually a scatterplot, a hexbin plot, a 2D histogram or a 2D density plot.

# %% [markdown]
# ### Univariate Analysis

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex');

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %% [markdown]
# ### Pair plot
# A 'pair plot' is also known as a scatterplot, in which one variable in the same data row is matched with another varialbes's value, like this: Pairs plots are just elaborations on this, showig all variables paired with all the other variables

# %%
sns.pairplot(df)

# %%
 # counting the number of smoker and non_smoker 
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.pairplot(df,hue='smoker');

# %% [markdown]
# ### Displot
# - helps us to check the distribution of the columns feature

# %%
sns.displot(df['tip']);

# %%
sns.displot(df['tip'],kde=False,bins=10);

# %% [markdown]
# ### Categorical Plots
# Seaborn also helps us in doing the anlaysis on Categroical Data points. In this section we will discuss about
# - boxplot
# - violinplot
# - count plot
# - bar plot

# %% [markdown]
# ### Countplot
# The sns.countplot() function in Seaborn is used to create a bar plot that displays the count of observations in each category of a categorical variable.

# %%
sns.countplot(x='sex',data=df);

# %%
sns.countplot(data =df,x='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
#let's visualize no of customer visit on day basis
sns.countplot(x='day',data=df);
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# from the above bar graph we can visualize the flow of customer is high in saturday,sunday,thursday and friday (which is the lowest flow)

# %% [markdown]
# ### bar plot

# %%
sns.barplot(x='sex',y='total_bill',data=df);

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x='smoker',y='total_bill',data=df);

# %%
sns.boxplot(x='day',y='total_bill',data=df,palette='rainbow');

# %%
sns.boxplot(data=df,orient='v')
# Out:
# <Axes: >

# %%
#categorize my data on some others categories
sns.boxplot(x='total_bill',y='day',hue='smoker',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# Violin Plot helps us to see both the distribution in therms of kernel density estimations and the box plot

# %%
sns.violinplot(x='total_bill',y='day',data=df,palette ='rainbow');
